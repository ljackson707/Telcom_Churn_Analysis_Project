# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib as matlib

# %%
telco_customer_data = pd.read_csv("TelcoData.csv")
telco_customer_data
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044         NaN  Female                  0      No         No              1
# 7045         NaN    Male                  0     Yes         No              2
# 7046         NaN    Male                  0      No         No              1
# 7047         NaN    Male                  0     Yes        Yes              1
# 7048         NaN    Male                  0     Yes        Yes              0
#
# ...

# %%
telco_customer_data.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7049.000000    7049.000000       7049.000000    7049.000000
# mean            0.162009       1.324585          1.222585       0.690878
# std             0.368485       0.642709          0.779068       0.833757
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_charges  total_charges  Tenure_month  partner_dependents  \
# count      7049.000000    7038.000000   7049.000000         7049.000000
# mean         64.747014    2283.043883     32.380068            1.083416
# std          30.099460    2266.521984     24.594926            1.226883
# ...

# %%
telco_customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7043 non-null   object
#  1   gender                  7049 non-null   object
#  2   is_senior_citizen       7049 non-null   int64
#  3   partner                 7049 non-null   object
#  4   dependents              7049 non-null   object
#  5   phone_service           7049 non-null   int64
#  6   internet_service        7049 non-null   int64
#  7   contract_type           7049 non-null   int64
#  8   payment_type            7049 non-null   object
#  9   monthly_charges         7049 non-null   float64
#  10  total_charges           7038 non-null   float64
#  11  churn                   7049 non-null   object
#  12  Tenure_month            7049 non-null   float64
#  13  FALSE                   7049 non-null   bool
# ...

# %%
telco_customer_data = telco_customer_data.rename(columns={'Monthly Tenure': 'monthly_tenure'})

# %%
telco_customer_data = telco_customer_data.rename(columns={'Internet Type': 'internet_type'})

# %%
telco_customer_data.groupby('internet_type').customer_id.count()
# Out:
# internet_type
# DSL                    2418
# Fiber Optic            3097
# No Internet Service    1528
# Name: customer_id, dtype: int64
